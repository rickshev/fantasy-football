# %%
import pandas as pd
import numpy as np
from sklearn.neighbors import KNeighborsClassifier

# %%
data = pd.read_csv("Data/fantasy.csv")
qb = pd.read_csv("Data/qb.csv")
rb = pd.read_csv("Data/rb.csv")
wr = pd.read_csv("Data/wr.csv")
te = pd.read_csv("Data/te.csv")

# %%
# Out:
#     Rk            Player   Tm FantPos  Age   G  GS  Cmp  Att   Yds  ...  2PP  \
# 0    7       Josh Allen   BUF      QB   24  16  16  396  572  4544  ...  0.0
# 1    8    Aaron Rodgers   GNB      QB   37  16  16  372  526  4299  ...  0.0
# 2    9     Kyler Murray   ARI      QB   23  16  16  375  558  3971  ...  0.0
# 3   10  Patrick Mahomes   KAN      QB   25  15  15  390  588  4740  ...  3.0
# 4   11   Deshaun Watson   HOU      QB   25  16  16  382  544  4823  ...  1.0
# 5   16   Russell Wilson   SEA      QB   32  16  16  384  558  4212  ...  1.0
# 6   23    Ryan Tannehill  TEN      QB   32  16  16  315  481  3819  ...  1.0
# 7   25         Tom Brady  TAM      QB   43  16  16  401  610  4633  ...  0.0
# 8   29    Justin Herbert  LAC      QB   22  15  15  396  595  4336  ...  2.0
# 9   30     Lamar Jackson  BAL      QB   23  15  15  242  376  2757  ...  1.0
# 10  45      Kirk Cousins  MIN      QB   32  16  16  349  516  4265  ...  5.0
# 11  79         Matt Ryan  ATL      QB   35  16  16  407  626  4581  ...  1.0
# 12  80        Derek Carr  LVR      QB   29  16  16  348  517  4103  ...  1.0
#
#     FantPt    PPR   DKPt   FDPt    VBD  PosRank  OvRank  Season  Value
# 0    395.0  396.1  418.1  405.6  113.0        1     7.0    2020    QB1
# 1    382.0  383.3  396.3  387.8  100.0        2     8.0    2020    QB1
# 2    379.0  378.7  400.7  390.7   96.0        3     9.0    2020    QB1
# 3    374.0  374.4  388.4  380.4   92.0        4    10.0    2020    QB1
# 4    369.0  369.3  385.3  376.3   87.0        5    11.0    2020    QB1
# 5    360.0  359.8  382.8  372.8   77.0        6    16.0    2020    QB1
# 6    343.0  344.4  358.4  350.9   61.0        7    23.0    2020    QB1
# 7    338.0  337.9  353.9  349.9   55.0        8    25.0    2020    QB1
# 8    333.0  332.8  349.8  342.8   50.0        9    29.0    2020    QB1
# 9    333.0  332.8  351.8  341.8   50.0       10    30.0    2020    QB1
# 10   306.0  306.2  330.2  319.2   24.0       11    45.0    2020    QB1
# 11   282.0  282.4  299.4  293.4    0.0       12     0.0    2020    QB1
# 12   272.0  272.1  295.1  281.1    0.0       13     0.0    2020    QB2
#
# [13 rows x 35 columns]
